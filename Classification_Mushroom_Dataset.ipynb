# %%
import pandas as pd
df = pd.read_csv('mushroom_dataset_new.csv')
df.head()
# Out:
#   cap-shape cap-surface cap-color  bruises    odor gill-attachment  \
# 0    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 1    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 2    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 3    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 4    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
#
#   gill-spacing gill-size gill-color stalk-shape  ... stalk-surface-below-ring  \
# 0      CROWDED    NARROW      WHITE    TAPERING  ...                   SMOOTH
# 1      CROWDED    NARROW      WHITE    TAPERING  ...                   SMOOTH
# 2      CROWDED    NARROW       PINK    TAPERING  ...                   SMOOTH
# 3      CROWDED    NARROW       PINK    TAPERING  ...                   SMOOTH
# 4      CROWDED    NARROW      BROWN    TAPERING  ...                   SMOOTH
#
#   stalk-color-above-ring stalk-color-below-ring veil-color ring-number  \
# 0                  WHITE                  WHITE      WHITE         ONE
# 1                  WHITE                  WHITE      WHITE         ONE
# 2                  WHITE                  WHITE      WHITE         ONE
# 3                  WHITE                  WHITE      WHITE         ONE
# 4                  WHITE                  WHITE      WHITE         ONE
#
#   ring-type spore-print-color population habitat mushroom
# 0   PENDANT            PURPLE    SEVERAL   WOODS   EDIBLE
# 1   PENDANT             BROWN    SEVERAL   WOODS   EDIBLE
# 2   PENDANT            PURPLE    SEVERAL   WOODS   EDIBLE
# 3   PENDANT             BROWN    SEVERAL   WOODS   EDIBLE
# 4   PENDANT            PURPLE    SEVERAL   WOODS   EDIBLE
#
# [5 rows x 22 columns]

# %%
df.head(44)
# Out:
#    cap-shape cap-surface cap-color  bruises    odor gill-attachment  \
# 0     CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 1     CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 2     CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 3     CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 4     CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 5     CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 6     CONVEX      SMOOTH     WHITE  BRUISES   ANISE            FREE
# 7     CONVEX      SMOOTH     WHITE  BRUISES   ANISE            FREE
# 8     CONVEX      SMOOTH     WHITE  BRUISES   ANISE            FREE
# 9     CONVEX      SMOOTH     WHITE  BRUISES   ANISE            FREE
# 10    CONVEX      SMOOTH     WHITE  BRUISES   ANISE            FREE
# 11    CONVEX      SMOOTH     WHITE  BRUISES   ANISE            FREE
# 12    CONVEX      SMOOTH    YELLOW  BRUISES  ALMOND            FREE
# 13    CONVEX      SMOOTH    YELLOW  BRUISES  ALMOND            FREE
# 14    CONVEX      SMOOTH    YELLOW  BRUISES  ALMOND            FREE
# 15    CONVEX      SMOOTH    YELLOW  BRUISES  ALMOND            FREE
# 16    CONVEX      SMOOTH    YELLOW  BRUISES  ALMOND            FREE
# 17    CONVEX      SMOOTH    YELLOW  BRUISES  ALMOND            FREE
# 18    CONVEX      SMOOTH    YELLOW  BRUISES   ANISE            FREE
# 19    CONVEX      SMOOTH    YELLOW  BRUISES   ANISE            FREE
# 20    CONVEX      SMOOTH    YELLOW  BRUISES   ANISE            FREE
# 21    CONVEX      SMOOTH    YELLOW  BRUISES   ANISE            FREE
# 22    CONVEX      SMOOTH    YELLOW  BRUISES   ANISE            FREE
# 23    CONVEX      SMOOTH    YELLOW  BRUISES   ANISE            FREE
# 24    CONVEX     FIBROUS     WHITE  BRUISES  ALMOND            FREE
# 25    CONVEX     FIBROUS     WHITE  BRUISES  ALMOND            FREE
# 26    CONVEX     FIBROUS     WHITE  BRUISES  ALMOND            FREE
# 27    CONVEX     FIBROUS     WHITE  BRUISES  ALMOND            FREE
# 28    CONVEX     FIBROUS     WHITE  BRUISES  ALMOND            FREE
# 29    CONVEX     FIBROUS     WHITE  BRUISES  ALMOND            FREE
# 30    CONVEX     FIBROUS     WHITE  BRUISES   ANISE            FREE
# 31    CONVEX     FIBROUS     WHITE  BRUISES   ANISE            FREE
# 32    CONVEX     FIBROUS     WHITE  BRUISES   ANISE            FREE
# 33    CONVEX     FIBROUS     WHITE  BRUISES   ANISE            FREE
# 34    CONVEX     FIBROUS     WHITE  BRUISES   ANISE            FREE
# 35    CONVEX     FIBROUS     WHITE  BRUISES   ANISE            FREE
# 36    CONVEX     FIBROUS    YELLOW  BRUISES  ALMOND            FREE
# 37    CONVEX     FIBROUS    YELLOW  BRUISES  ALMOND            FREE
# 38    CONVEX     FIBROUS    YELLOW  BRUISES  ALMOND            FREE
# 39    CONVEX     FIBROUS    YELLOW  BRUISES  ALMOND            FREE
# 40    CONVEX     FIBROUS    YELLOW  BRUISES  ALMOND            FREE
# 41    CONVEX     FIBROUS    YELLOW  BRUISES  ALMOND            FREE
# 42    CONVEX     FIBROUS    YELLOW  BRUISES   ANISE            FREE
# 43    CONVEX     FIBROUS    YELLOW  BRUISES   ANISE            FREE
#
#    gill-spacing gill-size gill-color stalk-shape  ...  \
# 0       CROWDED    NARROW      WHITE    TAPERING  ...
# 1       CROWDED    NARROW      WHITE    TAPERING  ...
# 2       CROWDED    NARROW       PINK    TAPERING  ...
# 3       CROWDED    NARROW       PINK    TAPERING  ...
# 4       CROWDED    NARROW      BROWN    TAPERING  ...
# 5       CROWDED    NARROW      BROWN    TAPERING  ...
# 6       CROWDED    NARROW      WHITE    TAPERING  ...
# 7       CROWDED    NARROW      WHITE    TAPERING  ...
# 8       CROWDED    NARROW       PINK    TAPERING  ...
# 9       CROWDED    NARROW       PINK    TAPERING  ...
# 10      CROWDED    NARROW      BROWN    TAPERING  ...
# 11      CROWDED    NARROW      BROWN    TAPERING  ...
# 12      CROWDED    NARROW      WHITE    TAPERING  ...
# 13      CROWDED    NARROW      WHITE    TAPERING  ...
# 14      CROWDED    NARROW       PINK    TAPERING  ...
# 15      CROWDED    NARROW       PINK    TAPERING  ...
# 16      CROWDED    NARROW      BROWN    TAPERING  ...
# 17      CROWDED    NARROW      BROWN    TAPERING  ...
# 18      CROWDED    NARROW      WHITE    TAPERING  ...
# 19      CROWDED    NARROW      WHITE    TAPERING  ...
# 20      CROWDED    NARROW       PINK    TAPERING  ...
# 21      CROWDED    NARROW       PINK    TAPERING  ...
# 22      CROWDED    NARROW      BROWN    TAPERING  ...
# 23      CROWDED    NARROW      BROWN    TAPERING  ...
# 24      CROWDED    NARROW      WHITE    TAPERING  ...
# 25      CROWDED    NARROW      WHITE    TAPERING  ...
# 26      CROWDED    NARROW       PINK    TAPERING  ...
# 27      CROWDED    NARROW       PINK    TAPERING  ...
# 28      CROWDED    NARROW      BROWN    TAPERING  ...
# 29      CROWDED    NARROW      BROWN    TAPERING  ...
# 30      CROWDED    NARROW      WHITE    TAPERING  ...
# 31      CROWDED    NARROW      WHITE    TAPERING  ...
# 32      CROWDED    NARROW       PINK    TAPERING  ...
# 33      CROWDED    NARROW       PINK    TAPERING  ...
# 34      CROWDED    NARROW      BROWN    TAPERING  ...
# 35      CROWDED    NARROW      BROWN    TAPERING  ...
# 36      CROWDED    NARROW      WHITE    TAPERING  ...
# 37      CROWDED    NARROW      WHITE    TAPERING  ...
# 38      CROWDED    NARROW       PINK    TAPERING  ...
# 39      CROWDED    NARROW       PINK    TAPERING  ...
# 40      CROWDED    NARROW      BROWN    TAPERING  ...
# 41      CROWDED    NARROW      BROWN    TAPERING  ...
# 42      CROWDED    NARROW      WHITE    TAPERING  ...
# 43      CROWDED    NARROW      WHITE    TAPERING  ...
#
#    stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                    SMOOTH                  WHITE                  WHITE
# 1                    SMOOTH                  WHITE                  WHITE
# 2                    SMOOTH                  WHITE                  WHITE
# 3                    SMOOTH                  WHITE                  WHITE
# 4                    SMOOTH                  WHITE                  WHITE
# 5                    SMOOTH                  WHITE                  WHITE
# 6                    SMOOTH                  WHITE                  WHITE
# 7                    SMOOTH                  WHITE                  WHITE
# 8                    SMOOTH                  WHITE                  WHITE
# 9                    SMOOTH                  WHITE                  WHITE
# 10                   SMOOTH                  WHITE                  WHITE
# 11                   SMOOTH                  WHITE                  WHITE
# 12                   SMOOTH                  WHITE                  WHITE
# 13                   SMOOTH                  WHITE                  WHITE
# 14                   SMOOTH                  WHITE                  WHITE
# 15                   SMOOTH                  WHITE                  WHITE
# 16                   SMOOTH                  WHITE                  WHITE
# 17                   SMOOTH                  WHITE                  WHITE
# 18                   SMOOTH                  WHITE                  WHITE
# 19                   SMOOTH                  WHITE                  WHITE
# 20                   SMOOTH                  WHITE                  WHITE
# 21                   SMOOTH                  WHITE                  WHITE
# 22                   SMOOTH                  WHITE                  WHITE
# 23                   SMOOTH                  WHITE                  WHITE
# 24                   SMOOTH                  WHITE                  WHITE
# 25                   SMOOTH                  WHITE                  WHITE
# 26                   SMOOTH                  WHITE                  WHITE
# 27                   SMOOTH                  WHITE                  WHITE
# 28                   SMOOTH                  WHITE                  WHITE
# 29                   SMOOTH                  WHITE                  WHITE
# 30                   SMOOTH                  WHITE                  WHITE
# 31                   SMOOTH                  WHITE                  WHITE
# 32                   SMOOTH                  WHITE                  WHITE
# 33                   SMOOTH                  WHITE                  WHITE
# 34                   SMOOTH                  WHITE                  WHITE
# 35                   SMOOTH                  WHITE                  WHITE
# 36                   SMOOTH                  WHITE                  WHITE
# 37                   SMOOTH                  WHITE                  WHITE
# 38                   SMOOTH                  WHITE                  WHITE
# 39                   SMOOTH                  WHITE                  WHITE
# 40                   SMOOTH                  WHITE                  WHITE
# 41                   SMOOTH                  WHITE                  WHITE
# 42                   SMOOTH                  WHITE                  WHITE
# 43                   SMOOTH                  WHITE                  WHITE
#
#    veil-color ring-number ring-type spore-print-color population habitat  \
# 0       WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 1       WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 2       WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 3       WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 4       WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 5       WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 6       WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 7       WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 8       WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 9       WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 10      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 11      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 12      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 13      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 14      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 15      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 16      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 17      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 18      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 19      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 20      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 21      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 22      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 23      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 24      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 25      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 26      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 27      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 28      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 29      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 30      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 31      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 32      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 33      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 34      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 35      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 36      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 37      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 38      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 39      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 40      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 41      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 42      WHITE         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 43      WHITE         ONE   PENDANT             BROWN    SEVERAL   WOODS
#
#    mushroom
# 0    EDIBLE
# 1    EDIBLE
# 2    EDIBLE
# 3    EDIBLE
# 4    EDIBLE
# 5    EDIBLE
# 6    EDIBLE
# 7    EDIBLE
# 8    EDIBLE
# 9    EDIBLE
# 10   EDIBLE
# 11   EDIBLE
# 12   EDIBLE
# 13   EDIBLE
# 14   EDIBLE
# 15   EDIBLE
# 16   EDIBLE
# 17   EDIBLE
# 18   EDIBLE
# 19   EDIBLE
# 20   EDIBLE
# 21   EDIBLE
# 22   EDIBLE
# 23   EDIBLE
# 24   EDIBLE
# 25   EDIBLE
# 26   EDIBLE
# 27   EDIBLE
# 28   EDIBLE
# 29   EDIBLE
# 30   EDIBLE
# 31   EDIBLE
# 32   EDIBLE
# 33   EDIBLE
# 34   EDIBLE
# 35   EDIBLE
# 36   EDIBLE
# 37   EDIBLE
# 38   EDIBLE
# 39   EDIBLE
# 40   EDIBLE
# 41   EDIBLE
# 42   EDIBLE
# 43   EDIBLE
#
# [44 rows x 22 columns]

# %%
df ['mushroom'].value_counts()
# Out:
# EDIBLE       4488
# POISONOUS    3928
# Name: mushroom, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
df = df.apply(LabelEncoder().fit_transform)
df
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             2            3          8        0     0                1
# 1             2            3          8        0     0                1
# 2             2            3          8        0     0                1
# 3             2            3          8        0     0                1
# 4             2            3          8        0     0                1
# ...         ...          ...        ...      ...   ...              ...
# 8411          4            3          0        1     6                0
# 8412          4            3          0        1     6                0
# 8413          4            3          0        1     6                0
# 8414          4            3          0        1     6                0
# 8415          4            3          0        1     6                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0                1          1          10            1  ...
# 1                1          1          10            1  ...
# 2                1          1           7            1  ...
# 3                1          1           7            1  ...
# 4                1          1           1            1  ...
# ...            ...        ...         ...          ...  ...
# 8411             0          0           1            0  ...
# 8412             0          0           1            0  ...
# 8413             0          0           1            0  ...
# 8414             0          0           1            0  ...
# 8415             0          0           1            0  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 0                            3                       7
# 1                            3                       7
# 2                            3                       7
# 3                            3                       7
# 4                            3                       7
# ...                        ...                     ...
# 8411                         3                       4
# 8412                         3                       4
# 8413                         3                       4
# 8414                         3                       4
# 8415                         3                       4
#
#       stalk-color-below-ring  veil-color  ring-number  ring-type  \
# 0                          7           2            1          4
# 1                          7           2            1          4
# 2                          7           2            1          4
# 3                          7           2            1          4
# 4                          7           2            1          4
# ...                      ...         ...          ...        ...
# 8411                       4           0            1          4
# 8412                       4           0            1          4
# 8413                       4           0            1          4
# 8414                       4           0            1          4
# 8415                       4           0            1          4
#
#       spore-print-color  population  habitat  mushroom
# 0                     6           4        6         0
# 1                     1           4        6         0
# 2                     6           4        6         0
# 3                     1           4        6         0
# 4                     6           4        6         0
# ...                 ...         ...      ...       ...
# 8411                  1           1        1         0
# 8412                  5           4        1         0
# 8413                  5           1        1         0
# 8414                  2           4        1         0
# 8415                  2           1        1         0
#
# [8416 rows x 22 columns]

# %%
df ['mushroom'].value_counts()
# Out:
# 0    4488
# 1    3928
# Name: mushroom, dtype: int64

# %%
from sklearn.model_selection import train_test_split

features = df.iloc[:,:21]
label = df.iloc[:,21] 

x_train, x_test, y_train, y_test = train_test_split(features, label, test_size = 0.20, random_state = 42)
x_test
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 7223          3            2          0        1     8                1
# 4591          2            2          9        1     4                1
# 2522          2            0          0        0     6                1
# 6223          2            3          7        1     8                1
# 2436          2            0          7        0     6                1
# ...         ...          ...        ...      ...   ...              ...
# 214           0            3          9        0     1                1
# 4812          3            0          3        1     4                1
# 4981          3            0          9        1     4                1
# 547           2            2          9        0     0                1
# 8337          3            3          0        1     6                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 7223             0          1           2            1  ...
# 4591             0          0           4            0  ...
# 2522             0          0           7            1  ...
# 6223             0          1           2            1  ...
# 2436             0          0           1            1  ...
# ...            ...        ...         ...          ...  ...
# 214              0          0           0            0  ...
# 4812             0          0           7            0  ...
# 4981             0          0           7            0  ...
# 547              0          0          10            0  ...
# 8337             0          0           6            0  ...
#
#       stalk-surface-above-ring  stalk-surface-below-ring  \
# 7223                         3                         2
# 4591                         2                         2
# 2522                         3                         3
# 6223                         3                         2
# 2436                         3                         3
# ...                        ...                       ...
# 214                          3                         3
# 4812                         2                         2
# 4981                         2                         2
# 547                          3                         3
# 8337                         3                         3
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-color  ring-number  \
# 7223                       7                       5           2            1
# 4591                       1                       5           2            1
# 2522                       5                       3           2            1
# 6223                       5                       5           2            1
# 2436                       7                       3           2            1
# ...                      ...                     ...         ...          ...
# 214                        7                       7           2            1
# 4812                       1                       0           2            1
# 4981                       5                       1           2            1
# 547                        7                       7           2            1
# 8337                       4                       4           1            1
#
#       ring-type  spore-print-color  population  habitat
# 7223          0                  7           4        1
# 4591          2                  3           4        0
# 2522          4                  1           5        6
# 6223          0                  7           4        6
# 2436          4                  0           5        6
# ...         ...                ...         ...      ...
# 214           4                  1           2        2
# 4812          2                  3           5        6
# 4981          2                  3           4        0
# 547           4                  0           2        0
# 8337          4                  8           1        1
#
# [1684 rows x 21 columns]

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model = model.fit(x_train, y_train)

# %%
#from sklearn.tree import DecisionTreeClassifier
#model = DecisionTreeClassifier()
#model = model.fit(x_train, y_train)

# %%
#from sklearn.neighbors import KNeighborsClassifier
#model = KNeighborsClassifier(n_neighbors)
#model = model.fit(x_train, y_train)

# %%
print(model.predict(x_test))
print(y_test)
# Out:
# [1 1 0 ... 1 0 0]
# 7223    1
# 4591    1
# 2522    0
# 6223    1
# 2436    0
#        ..
# 214     0
# 4812    1
# 4981    1
# 547     0
# 8337    0
# Name: mushroom, Length: 1684, dtype: int64

# %%
from sklearn.metrics import accuracy_score
hasil_prediksi = model.predict(x_test)
accuracy_score(y_test, hasil_prediksi)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(hasil_prediksi, y_test)
# Out:
# array([[903,   0],
#        [  0, 781]])

# %%
from sklearn.metrics import classification_report
print(classification_report( y_test, hasil_prediksi))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       903
#            1       1.00      1.00      1.00       781
#
#     accuracy                           1.00      1684
#    macro avg       1.00      1.00      1.00      1684
# weighted avg       1.00      1.00      1.00      1684
